# %% [markdown]
# <h1 style="padding-top: 25px;padding-bottom: 25px;text-align: left; padding-left: 10px; background-color: #DDDDDD;
#     color: black;"> <img style="float: left; padding-right: 10px;" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png" height="50px"> <a href='https://harvard-iacs.github.io/2023-AC215/' target='_blank'><strong><font color="#A41034">AC215: Productionizing AI (MLOps)</font></strong></a></h1>
#
# # **<font color="#A41034">Tutorial - Model Compression and Distillation</font>**
#
# **Harvard University**<br/>
# **Fall 2023**<br/>
# **Instructor:**<br/>
# Pavlos Protopapas
#
# <hr style="height:2pt">

# %% [markdown]
# ## **<font color="#A41034">Setup Notebook</font>**

# %% [markdown]
# **Copy & setup Colab with GPU**
#
# 1) Select "File" menu and pick "Save a copy in Drive"
# 2) This notebooks is already setup to use GPU but if you want to change it. Go to "Runtime" menu and select "Change runtime type". Then in the popup in "Hardware accelerator" select "GPU" and then click "Save"
# 3) If you want high RAM there is an option for that

# %% [markdown]
# **Installs**

# %%
# !pip install -q tensorflow_model_optimization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 5.2 MB/s eta 0:00:00

# %% [markdown]
# **Imports**

# %%
import os
import requests
import tempfile
import zipfile
import tarfile
import shutil
import math
import json
import time
import sys
import cv2
import string
import re
import subprocess
import hashlib
import numpy as np
import pandas as pd
import random
from glob import glob
import collections
import unicodedata
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.utils.layer_utils import count_params

# TF Hub
import tensorflow_hub as hub

# TF Optimization
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity.keras import prune_low_magnitude

# sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Verify Setup**
#
# It is a good practice to verify what version of TensorFlow & Keras you are using. Also verify if GPU is enabled and what GPU you have. Run the following cells to check the version of TensorFlow
#
# References:
# - [Eager Execution](https://www.tensorflow.org/guide/eager)
# - [Data Performance](https://www.tensorflow.org/guide/data_performance)

# %%
# Enable/Disable Eager Execution
# Reference: https://www.tensorflow.org/guide/eager
# TensorFlow's eager execution is an imperative programming environment that evaluates operations immediately,
# without building graphs

#tf.compat.v1.disable_eager_execution()
#tf.compat.v1.enable_eager_execution()

print("tensorflow version", tf.__version__)
print("Eager Execution Enabled:", tf.executing_eagerly())

# Get the number of replicas
strategy = tf.distribute.MirroredStrategy()
print("Number of replicas:", strategy.num_replicas_in_sync)

devices = tf.config.experimental.get_visible_devices()
print("Devices:", devices)
print(tf.config.experimental.list_logical_devices('GPU'))

print("GPU Available: ", tf.config.list_physical_devices('GPU'))
print("All Physical Devices", tf.config.list_physical_devices())

# Better performance with the tf.data API
# Reference: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Set the global random seed
tf.random.set_seed(215)
np.random.seed(215)
random.seed(215)
# Out:
# tensorflow version 2.14.0
# Eager Execution Enabled: True
# Number of replicas: 1
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# All Physical Devices [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Run this cell to see what GPU you have. If you get a P100 or T4 GPU that's great. If it's K80, it will still work but it will be slow.

# %%
# !nvidia-smi
# Out:
# Fri Dec  8 21:03:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    25W /  70W |    311MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# **Utils**
#
# Here are some util functions that we will be using for this notebook

# %%
def download_file(packet_url, base_path="", extract=False, headers=None):
  if base_path != "":
    if not os.path.exists(base_path):
      os.mkdir(base_path)
  packet_file = os.path.basename(packet_url)
  with requests.get(packet_url, stream=True, headers=headers) as r:
      r.raise_for_status()
      with open(os.path.join(base_path,packet_file), 'wb') as f:
          for chunk in r.iter_content(chunk_size=8192):
              f.write(chunk)

  if extract:
    if packet_file.endswith(".zip"):
      with zipfile.ZipFile(os.path.join(base_path,packet_file)) as zfile:
        zfile.extractall(base_path)
    else:
      packet_name = packet_file.split('.')[0]
      with tarfile.open(os.path.join(base_path,packet_file)) as tfile:
        tfile.extractall(base_path)

class JsonEncoder(json.JSONEncoder):
  def default(self, obj):
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, decimal.Decimal):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return super(JsonEncoder, self).default(obj)

experiment_name = "models"
def save_model(model,model_train_history,execution_time, learning_rate, epochs, optimizer, evaluation_results):
  model_name=model.name

  # Ensure path exists
  if not os.path.exists(experiment_name):
      os.mkdir(experiment_name)
  # Save the enitire model (structure + weights)
  model.save(os.path.join(experiment_name,model_name+".hdf5"))

  # Save only the weights
  model.save_weights(os.path.join(experiment_name,model_name+".h5"))

  # Save the structure only
  model_json = model.to_json()
  with open(os.path.join(experiment_name,model_name+".json"), "w") as json_file:
      json_file.write(model_json)

  model_size = get_model_size(model_name=model.name)

  # Save model history
  with open(os.path.join(experiment_name,model.name+"_train_history.json"), "w") as json_file:
      json_file.write(json.dumps(model_train_history,cls=JsonEncoder))

  trainable_parameters = count_params(model.trainable_weights)
  non_trainable_parameters = count_params(model.non_trainable_weights)

  # Save model metrics
  metrics ={
      "trainable_parameters":trainable_parameters,
      "execution_time":execution_time,
      "loss":evaluation_results[0],
      "accuracy":evaluation_results[1],
      "model_size":model_size,
      "learning_rate":learning_rate,
      "batch_size":batch_size,
      "epochs":epochs,
      "optimizer":type(optimizer).__name__
  }
  with open(os.path.join(experiment_name,model.name+"_model_metrics.json"), "w") as json_file:
      json_file.write(json.dumps(metrics,cls=JsonEncoder))

def get_model_size(model_name="model01"):
  model_size = os.stat(os.path.join(experiment_name,model_name+".hdf5")).st_size
  return model_size

def append_training_history(model_train_history, prev_model_train_history, metrics=["loss","val_loss","accuracy","val_accuracy"]):
  for metric in metrics:
    for metric_value in prev_model_train_history[metric]:
      model_train_history[metric].append(metric_value)

  return model_train_history

def evaluate_model(model,test_data, model_train_history,execution_time,
                        learning_rate, batch_size, epochs, optimizer,
                        save=True,
                        loss_metrics=["loss","val_loss"],
                        acc_metrics=["accuracy","val_accuracy"]):

  # Get the number of epochs the training was run for
  num_epochs = len(model_train_history[loss_metrics[0]])

  # Plot training results
  fig = plt.figure(figsize=(15,5))
  axs = fig.add_subplot(1,2,1)
  axs.set_title('Loss')
  # Plot all metrics
  for metric in loss_metrics:
      axs.plot(np.arange(0, num_epochs), model_train_history[metric], label=metric)
  axs.legend()

  axs = fig.add_subplot(1,2,2)
  axs.set_title('Accuracy')
  # Plot all metrics
  for metric in acc_metrics:
      axs.plot(np.arange(0, num_epochs), model_train_history[metric], label=metric)
  axs.legend()

  plt.show()

  # Evaluate on test data
  evaluation_results = model.evaluate(test_data, return_dict=True)
  print(evaluation_results)

  evaluation_results = [evaluation_results[loss_metrics[0]], evaluation_results[acc_metrics[0]]]

  if save:
    # Save model
    save_model(model, model_train_history,execution_time, learning_rate, epochs, optimizer, evaluation_results)

  return evaluation_results

# %% [markdown]
# ## **<font color="#A41034">Knowledge Distillation</font>**

# %% [markdown]
# This exercise aims to distill a mobile-net model that has been trained initially on imagenet and then trained on nature images portraying weather patterns (sunny, cloudy, etc). The learned mobilenet-base model will be considered the "professor" network. We will use distillation techniques to train a smaller, less sophisticated network that will call a "student" network. The hope is that the wisdom from the professor network will be distilled and used. Good luck with that!

# %% [markdown]
# ## **<font color="#A41034">Weather Dataset</font>**

# %% [markdown]
# #### **Download**

# %%
start_time = time.time()
download_file("https://github.com/dlops-io/datasets/releases/download/v1.0/weather_data.zip",
              base_path="dataset", extract=True)
download_file("https://github.com/dlops-io/models/releases/download/v2.0/distil_models.zip",
              base_path="", extract=True)
execution_time = (time.time() - start_time)/60.0
print("Download execution time (mins)",execution_time)
# Out:
# Download execution time (mins) 0.22823774814605713

# %% [markdown]
# ### **Load Data**
#
# * Read-in data as lists
# * Each element in data_x is the path to the image
# * Each element in data_y is the label of that image

# %%
# Load pre processed data
data_dir = "dataset/weather_data"

# Labels
label_names = os.listdir(data_dir)

# Number of unique labels
num_classes = len(label_names)
# Create label index for easy lookup
label2index = dict((name, index) for index, name in enumerate(label_names))
index2label = dict((index, name) for index, name in enumerate(label_names))

print("Number of classes:", num_classes)
print("Labels:", label_names)

# Generate a list of labels and path to text
data_x = []
data_y = []

for label in label_names:
  text_files = os.listdir(os.path.join(data_dir,label))
  data_x.extend([os.path.join(data_dir,label,f) for f in text_files])
  data_y.extend([label for f in text_files])

# Preview
print("data_x count:",len(data_x))
print("data_y count:",len(data_y))
print(data_x[:5])
print(data_y[:5])
# Out:
# Number of classes: 4
# Labels: ['sunrise', 'shine', 'cloudy', 'rain']
# data_x count: 1124
# data_y count: 1124
# ['dataset/weather_data/sunrise/sunrise337.jpg', 'dataset/weather_data/sunrise/sunrise141.jpg', 'dataset/weather_data/sunrise/sunrise75.jpg', 'dataset/weather_data/sunrise/sunrise187.jpg', 'dataset/weather_data/sunrise/sunrise114.jpg']
# ['sunrise', 'sunrise', 'sunrise', 'sunrise', 'sunrise']

# %%
# Generate a random sample of index
image_samples = np.random.randint(0,high=len(data_x)-1, size=12)

# View some images
fig = plt.figure(figsize=(20,8))
for i,img_idx in enumerate(image_samples):
    axs = fig.add_subplot(3,4,i+1)
    axs.set_title(data_y[img_idx])
    # Read image
    image = cv2.imread(data_x[img_idx])
    # convert to rgb
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis('off')

plt.show()

# %% [markdown]
# ## **<font color="#A41034">Build Data Pipelines</font>**

# %% [markdown]
# ### **Split Data**
# We split data into train, validation

# %%
validation_percent = 0.2

# Split data into train / validate
train_x, validate_x, train_y, validate_y = train_test_split(data_x, data_y, test_size=validation_percent)

print("train_x count:",len(train_x))
print("validate_x count:",len(validate_x))
# Out:
# train_x count: 899
# validate_x count: 225

# %% [markdown]
# ### **Create TF Datasets**

# %%
image_width = 224
image_height = 224
num_channels = 3
num_output_masks = 2
batch_size = 32
train_shuffle_buffer_size = len(train_x)
validation_shuffle_buffer_size = len(validate_x)

# Load Image
def load_image(path, label):
  image = tf.io.read_file(path)
  image = tf.image.decode_jpeg(image, channels=num_channels)
  image = tf.image.resize(image, [image_height,image_width])
  return image, label

# Normalize pixels
def normalize(image, label):
  image = image/255
  return image, label

# Convert all y labels to numbers
train_processed_y = [label2index[label] for label in train_y]
validate_processed_y = [label2index[label] for label in validate_y]

# Create TF Dataset
train_data = tf.data.Dataset.from_tensor_slices((train_x, train_processed_y))
validation_data = tf.data.Dataset.from_tensor_slices((validate_x, validate_processed_y))

#############
# Train data
#############
# Apply all data processing logic
train_data = train_data.shuffle(buffer_size=train_shuffle_buffer_size, seed=6767)
train_data = train_data.map(load_image, num_parallel_calls=AUTOTUNE)
train_data = train_data.map(normalize, num_parallel_calls=AUTOTUNE)
train_data = train_data.batch(batch_size)
train_data = train_data.prefetch(AUTOTUNE)

##################
# Validation data
##################
# Apply all data processing logic
validation_data = validation_data.shuffle(buffer_size=validation_shuffle_buffer_size, seed=8989)
validation_data = validation_data.map(load_image, num_parallel_calls=AUTOTUNE)
validation_data = validation_data.map(normalize, num_parallel_calls=AUTOTUNE)
validation_data = validation_data.batch(batch_size)
validation_data = validation_data.prefetch(AUTOTUNE)

print("train_data",train_data)
print("validation_data",validation_data)
# Out:
# train_data <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# validation_data <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## **<font color="#A41034">Build Teacher Model</font>**

# %% [markdown]
# #### **Teacher Model**
#
# Teacher model is a mobilenet_v2 model which we get from directly from tfhub.

# %%
def build_teacher_model(image_height, image_width, num_channels, num_classes):

  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels

  # Handle to pretrained model (Use a different model here)
  handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/5"

  # Regularize using L1
  kernel_weight = 0.02
  bias_weight = 0.02

  model = Sequential([
        keras.layers.InputLayer(input_shape=input_shape),
                                hub.KerasLayer(handle, trainable=False),
        keras.layers.Dense(units=64, activation='relu',
                           kernel_regularizer=keras.regularizers.l1(kernel_weight),
                           bias_regularizer=keras.regularizers.l1(bias_weight)
                           ),
        keras.layers.Dense(units=num_classes,
                           kernel_regularizer=keras.regularizers.l1(kernel_weight),
                           bias_regularizer=keras.regularizers.l1(bias_weight)),
  ],name='teacher_model')

  return model

# %% [markdown]
# #### **Train Teacher**
#
# Nothing magical about this step. We just train the teacher network.

# %%
############################
# Training Params
############################
learning_rate = 0.001
initial_epoch = 0
epochs = 50

# Load pre trained model during demos
LOAD_PREV_TRAINED = True

# Free up memory
K.clear_session()

# Optimizer
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
# Loss
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Build or Load Model
if not LOAD_PREV_TRAINED:
  # Build the teacher model
  teacher_model = build_teacher_model(image_height, image_width, num_channels, num_classes)
  print(teacher_model.summary())

  # Compile
  teacher_model.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=[keras.metrics.SparseCategoricalAccuracy()])

else:
  # Load model
  teacher_model = keras.models.load_model("distil_models/teacher_model.hdf5", custom_objects={'KerasLayer':hub.KerasLayer})
  print(teacher_model.summary())


  with open("distil_models/teacher_model_train_history.json") as json_file:
    prev_training_history = json.load(json_file)
  with open("distil_models/teacher_model_model_metrics.json") as json_file:
    model_metrics = json.load(json_file)

  epochs = len(prev_training_history["loss"])
  initial_epoch=epochs
  epochs=epochs+3 # Continue training for a few more epochs


# Train model
start_time = time.time()
training_results = teacher_model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        initial_epoch=initial_epoch,
        verbose=2)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history = training_results.history

if LOAD_PREV_TRAINED:
  # Append previous training history & time
  training_history = append_training_history(training_results.history,
                                             prev_training_history,
                                             metrics=["loss","val_loss","sparse_categorical_accuracy","val_sparse_categorical_accuracy"])
  execution_time = model_metrics["execution_time"] + execution_time

# Evaluate model
evaluate_model(teacher_model,validation_data, training_history,execution_time,
                    learning_rate, batch_size, epochs, optimizer,
                    save=True,
                    loss_metrics=["loss","val_loss"],
                    acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])
# Out:
# Model: "teacher_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 64)                81984
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2340228 (8.93 MB)
# Trainable params: 82244 (321.27 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________
# None
# Epoch 51/53
# 29/29 - 14s - loss: 20.2603 - sparse_categorical_accuracy: 0.2002 - val_loss: 19.5461 - val_sparse_categorical_accuracy: 0.2622 - 14s/epoch - 472ms/step
# Epoch 52/53
# 29/29 - 2s - loss: 19.3287 - sparse_categorical_accuracy: 0.2113 - val_loss: 18.7653 - val_sparse_categorical_accuracy: 0.2889 - 2s/epoch - 75ms/step
# Epoch 53/53
# 29/29 - 2s - loss: 18.5433 - sparse_categorical_accuracy: 0.2636 - val_loss: 18.0655 - val_sparse_categorical_accuracy: 0.3244 - 2s/epoch - 73ms/step
# Training execution time (mins) 0.3013539711634318
# 8/8 [==============================] - 0s 35ms/step - loss: 18.0655 - sparse_categorical_accuracy: 0.3244
# {'loss': 18.065528869628906, 'sparse_categorical_accuracy': 0.324444442987442}
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# [18.065528869628906, 0.324444442987442]

# %%
#!zip -r models.zip models

# %% [markdown]
# ## **<font color="#A41034">Build Student Model</font>**

# %% [markdown]
# #### **Student Model**
#
# Student model is just 2 conv layers with max pooling and a dense layer

# %%
def build_student_model(image_height, image_width, num_channels, num_classes, model_name='student'):
  # Model input
  input_shape = [image_height, image_width, num_channels]  # height, width, channels

  model = Sequential(
      [
        keras.Input(shape=input_shape),
        keras.layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(2, 2), padding="same",
                            kernel_initializer=keras.initializers.GlorotUniform(seed=1212)),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),
        keras.layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(2, 2), padding="same",
                            kernel_initializer=keras.initializers.GlorotUniform(seed=2121)),
        keras.layers.LeakyReLU(alpha=0.2),
        keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same"),
        keras.layers.Flatten(),
        # keras.layers.Dense(units=32, kernel_initializer=keras.initializers.GlorotUniform(seed=2323)),
        keras.layers.Dense(units=num_classes, kernel_initializer=keras.initializers.GlorotUniform(seed=3434))
      ],
      name=model_name)

  return model

# %% [markdown]
# #### **Train Student from Scratch**
#
# We do this for for comparison purposes

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 5

# Free up memory
K.clear_session()

# Build the model
student_model_scratch = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_scratch')
print(student_model_scratch.summary())

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Loss
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
student_model_scratch.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=[keras.metrics.SparseCategoricalAccuracy()])

# Train teacher model
start_time = time.time()
training_results = student_model_scratch.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history = training_results.history

# Evaluate model
evaluate_model(student_model_scratch,validation_data, training_history,execution_time,
                    learning_rate, batch_size, epochs, optimizer,
                    save=True,
                    loss_metrics=["loss","val_loss"],
                    acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])
# Out:
# Model: "student_scratch"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 8)       224
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/5
# 29/29 [==============================] - 5s 62ms/step - loss: 1.1852 - sparse_categorical_accuracy: 0.4727 - val_loss: 0.9072 - val_sparse_categorical_accuracy: 0.7378
# Epoch 2/5
# 29/29 [==============================] - 2s 63ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.6808 - val_loss: 0.6807 - val_sparse_categorical_accuracy: 0.7867
# Epoch 3/5
# 29/29 [==============================] - 2s 62ms/step - loss: 0.6033 - sparse_categorical_accuracy: 0.7842 - val_loss: 0.6127 - val_sparse_categorical_accuracy: 0.7867
# Epoch 4/5
# 29/29 [==============================] - 2s 67ms/step - loss: 0.5082 - sparse_categorical_accuracy: 0.8176 - val_loss: 0.5300 - val_sparse_categorical_accuracy: 0.8533
# Epoch 5/5
# 29/29 [==============================] - 2s 66ms/step - loss: 0.4786 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.5729 - val_sparse_categorical_accuracy: 0.7867
# Training execution time (mins) 0.20460518995920818
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5729 - sparse_categorical_accuracy: 0.7867
# {'loss': 0.5729422569274902, 'sparse_categorical_accuracy': 0.7866666913032532}
# [0.5729422569274902, 0.7866666913032532]

# %% [markdown]
# ## **<font color="#A41034">Build Distiller (Plain)</font>**

# %%
class Distiller(Model):
    def __init__(self, teacher, student):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student

    def compile(self, optimizer, metrics, student_loss_fn, distillation_loss_fn, Lambda = 0.1, temperature=3):
      """
      optimizer: Keras optimizer for the student weights
      metrics: Keras metrics for evaluation
      student_loss_fn: Loss function of difference between student predictions and ground-truth
      distillation_loss_fn: Loss function of difference between soft student predictions and soft teacher predictions
      lambda: weight to student_loss_fn and 1-alpha to distillation_loss_fn
      temperature: Temperature for softening probability distributions. Larger temperature gives softer distributions.
      """
      super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
      self.student_loss_fn = student_loss_fn
      self.distillation_loss_fn = distillation_loss_fn

      #hyper-parameters
      self.Lambda = Lambda
      self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher (professor)
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            #tf.print("\n\nteacher_withTemp is: \n", tf.nn.softmax(teacher_predictions / self.temperature, axis=1))
            #tf.print("student_withTemp is: \n", tf.nn.softmax(student_predictions / self.temperature, axis=1))
            print("\n\n")

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
            )
            loss = self.Lambda * student_loss + (1 - self.Lambda) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# ## **<font color="#A41034">Distill Teacher to Student</font>**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 35
Lambda = 0.75
temperature= 12

# Free up memory
K.clear_session()

# Build Student model
student_model = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_distill')
print(student_model.summary())

# Build the distiller model
distiller_model = Distiller(teacher=teacher_model, student=student_model)

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Loss
student_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#distillation_loss = keras.losses.KLDivergence()
distillation_loss = keras.losses.CategoricalCrossentropy(from_logits=False)

# Compile
distiller_model.compile(
    optimizer=optimizer,
    student_loss_fn=student_loss,
    distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    Lambda=Lambda,
    temperature=temperature
)

# Distill teacher to student
start_time = time.time()
training_results = distiller_model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history = training_results.history

# Evaluate model
evaluation_results = evaluate_model(distiller_model,validation_data,
               training_history,execution_time,learning_rate, batch_size, epochs, optimizer,
               save=False,
               loss_metrics=["student_loss","distillation_loss","val_student_loss"],
               acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])

# Save student model
save_model(student_model,training_history,execution_time,learning_rate, epochs, optimizer, evaluation_results)
# Out:
# Model: "student_distill"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 8)       224
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/35
#
#
#
#
#
#
# 29/29 [==============================] - 3s 61ms/step - sparse_categorical_accuracy: 0.5439 - student_loss: 1.1449 - distillation_loss: 1.3877 - val_sparse_categorical_accuracy: 0.7333 - val_student_loss: 0.4740
# Epoch 2/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.7675 - student_loss: 0.6701 - distillation_loss: 1.4026 - val_sparse_categorical_accuracy: 0.8311 - val_student_loss: 0.3215
# Epoch 3/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.8042 - student_loss: 0.5658 - distillation_loss: 1.4137 - val_sparse_categorical_accuracy: 0.7956 - val_student_loss: 0.3966
# Epoch 4/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.7964 - student_loss: 0.5177 - distillation_loss: 1.4191 - val_sparse_categorical_accuracy: 0.8622 - val_student_loss: 0.4202
# Epoch 5/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8443 - student_loss: 0.4508 - distillation_loss: 1.4188 - val_sparse_categorical_accuracy: 0.8533 - val_student_loss: 8.6568e-04
# Epoch 6/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.8376 - student_loss: 0.4497 - distillation_loss: 1.4211 - val_sparse_categorical_accuracy: 0.8178 - val_student_loss: 0.0395
# Epoch 7/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.8443 - student_loss: 0.4027 - distillation_loss: 1.4197 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.2032
# Epoch 8/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.8509 - student_loss: 0.3859 - distillation_loss: 1.4206 - val_sparse_categorical_accuracy: 0.8978 - val_student_loss: 0.0256
# Epoch 9/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.8487 - student_loss: 0.3890 - distillation_loss: 1.4177 - val_sparse_categorical_accuracy: 0.8844 - val_student_loss: 0.0134
# Epoch 10/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.8810 - student_loss: 0.3355 - distillation_loss: 1.4143 - val_sparse_categorical_accuracy: 0.8711 - val_student_loss: 0.0380
# Epoch 11/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.8865 - student_loss: 0.2933 - distillation_loss: 1.4170 - val_sparse_categorical_accuracy: 0.8578 - val_student_loss: 1.5807
# Epoch 12/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.8832 - student_loss: 0.3211 - distillation_loss: 1.4168 - val_sparse_categorical_accuracy: 0.8756 - val_student_loss: 5.3518
# Epoch 13/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.8921 - student_loss: 0.2922 - distillation_loss: 1.4155 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.0081
# Epoch 14/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9110 - student_loss: 0.2639 - distillation_loss: 1.4141 - val_sparse_categorical_accuracy: 0.9022 - val_student_loss: 1.0610e-05
# Epoch 15/35
# 29/29 [==============================] - 2s 68ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.2766 - distillation_loss: 1.4193 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 0.1787
# Epoch 16/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9199 - student_loss: 0.2278 - distillation_loss: 1.4162 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 2.0579
# Epoch 17/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9244 - student_loss: 0.2081 - distillation_loss: 1.4140 - val_sparse_categorical_accuracy: 0.9422 - val_student_loss: 0.3350
# Epoch 18/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9210 - student_loss: 0.2095 - distillation_loss: 1.4170 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.0013
# Epoch 19/35
# 29/29 [==============================] - 2s 66ms/step - sparse_categorical_accuracy: 0.9422 - student_loss: 0.1870 - distillation_loss: 1.4158 - val_sparse_categorical_accuracy: 0.8267 - val_student_loss: 6.0318e-05
# Epoch 20/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9232 - student_loss: 0.2026 - distillation_loss: 1.4232 - val_sparse_categorical_accuracy: 0.9422 - val_student_loss: 0.4581
# Epoch 21/35
# 29/29 [==============================] - 2s 66ms/step - sparse_categorical_accuracy: 0.9355 - student_loss: 0.1957 - distillation_loss: 1.4193 - val_sparse_categorical_accuracy: 0.9156 - val_student_loss: 0.0091
# Epoch 22/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9377 - student_loss: 0.1726 - distillation_loss: 1.4222 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.0684
# Epoch 23/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.9522 - student_loss: 0.1512 - distillation_loss: 1.4193 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.0127
# Epoch 24/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9600 - student_loss: 0.1416 - distillation_loss: 1.4233 - val_sparse_categorical_accuracy: 0.8844 - val_student_loss: 0.2129
# Epoch 25/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.9488 - student_loss: 0.1471 - distillation_loss: 1.4215 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.0699
# Epoch 26/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.1276 - distillation_loss: 1.4243 - val_sparse_categorical_accuracy: 0.9422 - val_student_loss: 0.0015
# Epoch 27/35
# 29/29 [==============================] - 2s 66ms/step - sparse_categorical_accuracy: 0.9655 - student_loss: 0.1252 - distillation_loss: 1.4219 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.0305
# Epoch 28/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9555 - student_loss: 0.1288 - distillation_loss: 1.4336 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 2.2411e-05
# Epoch 29/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9600 - student_loss: 0.1223 - distillation_loss: 1.4281 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.4301
# Epoch 30/35
# 29/29 [==============================] - 2s 56ms/step - sparse_categorical_accuracy: 0.9677 - student_loss: 0.1125 - distillation_loss: 1.4270 - val_sparse_categorical_accuracy: 0.9156 - val_student_loss: 0.0051
# Epoch 31/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9677 - student_loss: 0.1090 - distillation_loss: 1.4339 - val_sparse_categorical_accuracy: 0.9156 - val_student_loss: 0.0018
# Epoch 32/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9755 - student_loss: 0.0997 - distillation_loss: 1.4316 - val_sparse_categorical_accuracy: 0.9200 - val_student_loss: 0.8307
# Epoch 33/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9511 - student_loss: 0.1393 - distillation_loss: 1.4303 - val_sparse_categorical_accuracy: 0.9378 - val_student_loss: 0.0954
# Epoch 34/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.1347 - distillation_loss: 1.4362 - val_sparse_categorical_accuracy: 0.9022 - val_student_loss: 0.0034
# Epoch 35/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9611 - student_loss: 0.1419 - distillation_loss: 1.4350 - val_sparse_categorical_accuracy: 0.9289 - val_student_loss: 0.0082
# Training execution time (mins) 1.1301200230916342
# 8/8 [==============================] - 0s 28ms/step - sparse_categorical_accuracy: 0.9289 - student_loss: 0.2360
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# {'sparse_categorical_accuracy': 0.9288889169692993, 'student_loss': 0.19967523217201233}

# %%
print(Distiller.__bases__)
# Out:
# (<class 'keras.src.engine.training.Model'>,)

# %% [markdown]
# # Online Distillation
# * This technique is also called as DML (Deep Mutual Learning)
# * Knowlege is distilled among peers. No teacher is invovled.
# * Original Paper: [Zhang 2018](https://openaccess.thecvf.com/content_cvpr_2018/papers/Zhang_Deep_Mutual_Learning_CVPR_2018_paper.pdf).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **<font color="#A41034">Build 2 Student Models</font>**

# %%
## For simplicity, let's try 2 identical students.
## But there is no requirement for both student models to be identical.
## The students can be in any architecture.

student_model_1 = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_1')
print(student_model_1.summary())

student_model_2 = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_2')
print(student_model_2.summary())
# Out:
# Model: "student_online_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_1 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_4 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ## **<font color="#A41034">Build 2 Distillers (1 per student)</font>**

# %%
# Build the distiller models
distiller_model_1 = Distiller(student=student_model_1, teacher=student_model_2)  ## student_1 being taught by student_2
distiller_model_2 = Distiller(student=student_model_2, teacher=student_model_1)  ## student_2 being taught by student_1

## Define the loss functions
student_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
distillation_loss = keras.losses.KLDivergence()

# %% [markdown]
# ## **<font color="#A41034">Distill Among 2 Students</font>**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 35
Lambda = 0.50                ## currently 1:1 ratio between cross_entropy loss & KL divergence loss
temperature= 1               ## original paper does not utilize soft label, hence, there is no concept of temperature.

# Free up memory
K.clear_session()

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

# Compile
distiller_model_1.compile(
    optimizer=optimizer,
    student_loss_fn=student_loss,
    distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    Lambda=Lambda,
    temperature=temperature
)

distiller_model_2.compile(
    optimizer=optimizer,
    student_loss_fn=student_loss,
    distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
    Lambda=Lambda,
    temperature=temperature
)

# Distill among peers
start_time = time.time()
training_results_2 = distiller_model_2.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history_2 = training_results_2.history

# Evaluate model
evaluation_results_2 = evaluate_model(distiller_model_2,validation_data,
               training_history_2,execution_time,learning_rate, batch_size, epochs, optimizer,
               save=False,
               loss_metrics=["student_loss","distillation_loss","val_student_loss"],
               acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])

# Save student model
save_model(student_model_2,training_history_2,execution_time,learning_rate, epochs, optimizer, evaluation_results_2)
# Out:
# Epoch 1/35
#
#
#
#
#
#
# 29/29 [==============================] - 4s 53ms/step - sparse_categorical_accuracy: 0.5628 - student_loss: 1.1639 - distillation_loss: 0.0701 - val_sparse_categorical_accuracy: 0.6222 - val_student_loss: 1.5420
# Epoch 2/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.7397 - student_loss: 0.9619 - distillation_loss: 0.1556 - val_sparse_categorical_accuracy: 0.7067 - val_student_loss: 0.6706
# Epoch 3/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.7853 - student_loss: 0.9059 - distillation_loss: 0.1721 - val_sparse_categorical_accuracy: 0.8133 - val_student_loss: 0.4103
# Epoch 4/35
# 29/29 [==============================] - 2s 67ms/step - sparse_categorical_accuracy: 0.8065 - student_loss: 0.8641 - distillation_loss: 0.1693 - val_sparse_categorical_accuracy: 0.8444 - val_student_loss: 0.6676
# Epoch 5/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8565 - student_loss: 0.8010 - distillation_loss: 0.1862 - val_sparse_categorical_accuracy: 0.8756 - val_student_loss: 0.3692
# Epoch 6/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.8687 - student_loss: 0.7617 - distillation_loss: 0.2037 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.5409
# Epoch 7/35
# 29/29 [==============================] - 2s 56ms/step - sparse_categorical_accuracy: 0.8888 - student_loss: 0.7423 - distillation_loss: 0.2114 - val_sparse_categorical_accuracy: 0.8267 - val_student_loss: 0.4749
# Epoch 8/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.8854 - student_loss: 0.7237 - distillation_loss: 0.2210 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.4154
# Epoch 9/35
# 29/29 [==============================] - 2s 59ms/step - sparse_categorical_accuracy: 0.9032 - student_loss: 0.7047 - distillation_loss: 0.2249 - val_sparse_categorical_accuracy: 0.8222 - val_student_loss: 0.8203
# Epoch 10/35
# 29/29 [==============================] - 2s 59ms/step - sparse_categorical_accuracy: 0.8988 - student_loss: 0.7071 - distillation_loss: 0.2215 - val_sparse_categorical_accuracy: 0.8978 - val_student_loss: 0.4837
# Epoch 11/35
# 29/29 [==============================] - 2s 69ms/step - sparse_categorical_accuracy: 0.9010 - student_loss: 0.6958 - distillation_loss: 0.2366 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 0.8529
# Epoch 12/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9177 - student_loss: 0.6852 - distillation_loss: 0.2354 - val_sparse_categorical_accuracy: 0.9289 - val_student_loss: 0.4334
# Epoch 13/35
# 29/29 [==============================] - 2s 57ms/step - sparse_categorical_accuracy: 0.9288 - student_loss: 0.6717 - distillation_loss: 0.2368 - val_sparse_categorical_accuracy: 0.8756 - val_student_loss: 0.7926
# Epoch 14/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9355 - student_loss: 0.6614 - distillation_loss: 0.2362 - val_sparse_categorical_accuracy: 0.8978 - val_student_loss: 0.6034
# Epoch 15/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.9333 - student_loss: 0.6650 - distillation_loss: 0.2423 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.7248
# Epoch 16/35
# 29/29 [==============================] - 2s 56ms/step - sparse_categorical_accuracy: 0.9422 - student_loss: 0.6540 - distillation_loss: 0.2417 - val_sparse_categorical_accuracy: 0.9022 - val_student_loss: 0.5570
# Epoch 17/35
# 29/29 [==============================] - 2s 66ms/step - sparse_categorical_accuracy: 0.9422 - student_loss: 0.6425 - distillation_loss: 0.2454 - val_sparse_categorical_accuracy: 0.8356 - val_student_loss: 0.6365
# Epoch 18/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9433 - student_loss: 0.6637 - distillation_loss: 0.2368 - val_sparse_categorical_accuracy: 0.8133 - val_student_loss: 0.5186
# Epoch 19/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.9410 - student_loss: 0.6421 - distillation_loss: 0.2491 - val_sparse_categorical_accuracy: 0.8844 - val_student_loss: 0.4133
# Epoch 20/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9600 - student_loss: 0.6261 - distillation_loss: 0.2492 - val_sparse_categorical_accuracy: 0.7956 - val_student_loss: 0.3521
# Epoch 21/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.9221 - student_loss: 0.6681 - distillation_loss: 0.2384 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.6275
# Epoch 22/35
# 29/29 [==============================] - 2s 59ms/step - sparse_categorical_accuracy: 0.9633 - student_loss: 0.6300 - distillation_loss: 0.2597 - val_sparse_categorical_accuracy: 0.8444 - val_student_loss: 0.7862
# Epoch 23/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9288 - student_loss: 0.6560 - distillation_loss: 0.2531 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.5610
# Epoch 24/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.9600 - student_loss: 0.6212 - distillation_loss: 0.2488 - val_sparse_categorical_accuracy: 0.9289 - val_student_loss: 0.7184
# Epoch 25/35
# 29/29 [==============================] - 2s 75ms/step - sparse_categorical_accuracy: 0.9689 - student_loss: 0.6055 - distillation_loss: 0.2606 - val_sparse_categorical_accuracy: 0.8622 - val_student_loss: 0.7051
# Epoch 26/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.6260 - distillation_loss: 0.2472 - val_sparse_categorical_accuracy: 0.9289 - val_student_loss: 0.6740
# Epoch 27/35
# 29/29 [==============================] - 2s 72ms/step - sparse_categorical_accuracy: 0.9655 - student_loss: 0.6115 - distillation_loss: 0.2578 - val_sparse_categorical_accuracy: 0.8889 - val_student_loss: 0.5075
# Epoch 28/35
# 29/29 [==============================] - 2s 66ms/step - sparse_categorical_accuracy: 0.9622 - student_loss: 0.6135 - distillation_loss: 0.2506 - val_sparse_categorical_accuracy: 0.9022 - val_student_loss: 0.8301
# Epoch 29/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9800 - student_loss: 0.5933 - distillation_loss: 0.2610 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 1.0381
# Epoch 30/35
# 29/29 [==============================] - 2s 64ms/step - sparse_categorical_accuracy: 0.9778 - student_loss: 0.5957 - distillation_loss: 0.2607 - val_sparse_categorical_accuracy: 0.9422 - val_student_loss: 0.6944
# Epoch 31/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9778 - student_loss: 0.6001 - distillation_loss: 0.2537 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.5593
# Epoch 32/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9833 - student_loss: 0.5941 - distillation_loss: 0.2541 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 0.3836
# Epoch 33/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9778 - student_loss: 0.5848 - distillation_loss: 0.2675 - val_sparse_categorical_accuracy: 0.9111 - val_student_loss: 0.4583
# Epoch 34/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.9811 - student_loss: 0.6269 - distillation_loss: 0.2626 - val_sparse_categorical_accuracy: 0.8267 - val_student_loss: 0.9375
# Epoch 35/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.6403 - distillation_loss: 0.2490 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.8348
# Training execution time (mins) 1.110093386967977
# 8/8 [==============================] - 0s 34ms/step - sparse_categorical_accuracy: 0.9244 - student_loss: 0.6217
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# {'sparse_categorical_accuracy': 0.9244444370269775, 'student_loss': 0.5016381144523621}

# %% [markdown]
# ## **<font color="#A41034">Build 10 Student Models</font>**

# %%
## For simplicity, let's try 2 identical students.
## But there is no requirement for both student models to be identical.
## The students can be in any architecture.

student_model_a = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_a')
print(student_model_a.summary())

student_model_b = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_b')
print(student_model_b.summary())

student_model_c = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_c')
print(student_model_c.summary())

student_model_d = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_d')
print(student_model_d.summary())

student_model_e = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_e')
print(student_model_e.summary())

student_model_f = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_f')
print(student_model_f.summary())

student_model_g = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_g')
print(student_model_g.summary())

student_model_h = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_h')
print(student_model_h.summary())

student_model_i = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_i')
print(student_model_i.summary())

student_model_j = build_student_model(image_height, image_width, num_channels, num_classes, model_name='student_online_j')
print(student_model_j.summary())
# Out:
# Model: "student_online_a"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 8)       224
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_b"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_1 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_c"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_4 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_d"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_6 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 3136)              0
#
#  dense_3 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_e"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 112, 112, 8)       224
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 112, 112, 8)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 56, 56, 8)         0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_f"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 112, 112, 8)       224
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 112, 112, 8)       0
#
#  max_pooling2d_10 (MaxPooli  (None, 56, 56, 8)         0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 16)        1168
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_5 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_g"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 112, 112, 8)       224
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 112, 112, 8)       0
#
#  max_pooling2d_12 (MaxPooli  (None, 56, 56, 8)         0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 16)        1168
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 3136)              0
#
#  dense_6 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_h"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 112, 112, 8)       224
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 112, 112, 8)       0
#
#  max_pooling2d_14 (MaxPooli  (None, 56, 56, 8)         0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 16)        1168
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  max_pooling2d_15 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 3136)              0
#
#  dense_7 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_i"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 112, 112, 8)       224
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 112, 112, 8)       0
#
#  max_pooling2d_16 (MaxPooli  (None, 56, 56, 8)         0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 16)        1168
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  max_pooling2d_17 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  flatten_8 (Flatten)         (None, 3136)              0
#
#  dense_8 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model: "student_online_j"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 112, 112, 8)       224
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 112, 112, 8)       0
#
#  max_pooling2d_18 (MaxPooli  (None, 56, 56, 8)         0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 16)        1168
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 28, 28, 16)        0
#
#  max_pooling2d_19 (MaxPooli  (None, 14, 14, 16)        0
#  ng2D)
#
#  flatten_9 (Flatten)         (None, 3136)              0
#
#  dense_9 (Dense)             (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ## **<font color="#A41034">Build 10 Distillers (1 per student)</font>**

# %%
# Build the distiller models
distiller_model_a = Distiller(student=student_model_a, teacher=student_model_j)
distiller_model_b = Distiller(student=student_model_b, teacher=student_model_a)
distiller_model_c = Distiller(student=student_model_c, teacher=student_model_b)
distiller_model_d = Distiller(student=student_model_d, teacher=student_model_c)
distiller_model_e = Distiller(student=student_model_e, teacher=student_model_d)
distiller_model_f = Distiller(student=student_model_f, teacher=student_model_e)
distiller_model_g = Distiller(student=student_model_g, teacher=student_model_f)
distiller_model_h = Distiller(student=student_model_h, teacher=student_model_g)
distiller_model_i = Distiller(student=student_model_i, teacher=student_model_h)
distiller_model_j = Distiller(student=student_model_j, teacher=student_model_i)


## Define the loss functions
student_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
distillation_loss = keras.losses.KLDivergence()

# %% [markdown]
# ## **<font color="#A41034">Distill Among 10 Students</font>**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 35
Lambda = 0.50                ## currently 1:1 ratio between cross_entropy loss & KL divergence loss
temperature= 1               ## original paper does not utilize soft label, hence, there is no concept of temperature.

# Free up memory
K.clear_session()

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

# Compile
distiller_model_a.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_b.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_c.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_d.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_e.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_f.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_g.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_h.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_i.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)
distiller_model_j.compile(
    optimizer=optimizer, student_loss_fn=student_loss, distillation_loss_fn=distillation_loss,
    metrics=[keras.metrics.SparseCategoricalAccuracy()], Lambda=Lambda, temperature=temperature)


# Distill among peers
start_time = time.time()
training_results_a = distiller_model_a.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history_a = training_results_a.history

# Evaluate model
evaluation_results_a = evaluate_model(distiller_model_a,validation_data,
               training_history_a,execution_time,learning_rate, batch_size, epochs, optimizer,
               save=False,
               loss_metrics=["student_loss","distillation_loss","val_student_loss"],
               acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])

# Save student model
save_model(student_model_a,training_history_a,execution_time,learning_rate, epochs, optimizer, evaluation_results_a)
# Out:
# Epoch 1/35
#
#
#
#
#
#
# 29/29 [==============================] - 3s 59ms/step - sparse_categorical_accuracy: 0.5050 - student_loss: 1.1700 - distillation_loss: 0.0657 - val_sparse_categorical_accuracy: 0.6844 - val_student_loss: 0.6351
# Epoch 2/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.7597 - student_loss: 0.9086 - distillation_loss: 0.1758 - val_sparse_categorical_accuracy: 0.7911 - val_student_loss: 0.6186
# Epoch 3/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8276 - student_loss: 0.8599 - distillation_loss: 0.1722 - val_sparse_categorical_accuracy: 0.7467 - val_student_loss: 1.5726
# Epoch 4/35
# 29/29 [==============================] - 2s 65ms/step - sparse_categorical_accuracy: 0.8420 - student_loss: 0.8261 - distillation_loss: 0.1874 - val_sparse_categorical_accuracy: 0.8267 - val_student_loss: 1.5493
# Epoch 5/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8432 - student_loss: 0.7545 - distillation_loss: 0.2111 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.6552
# Epoch 6/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8921 - student_loss: 0.7350 - distillation_loss: 0.2235 - val_sparse_categorical_accuracy: 0.8844 - val_student_loss: 0.7079
# Epoch 7/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.8865 - student_loss: 0.7249 - distillation_loss: 0.2139 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.3672
# Epoch 8/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9010 - student_loss: 0.6812 - distillation_loss: 0.2430 - val_sparse_categorical_accuracy: 0.8978 - val_student_loss: 0.7641
# Epoch 9/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9143 - student_loss: 0.6916 - distillation_loss: 0.2259 - val_sparse_categorical_accuracy: 0.8756 - val_student_loss: 1.0418
# Epoch 10/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9221 - student_loss: 0.6835 - distillation_loss: 0.2311 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.7887
# Epoch 11/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9099 - student_loss: 0.6934 - distillation_loss: 0.2360 - val_sparse_categorical_accuracy: 0.9156 - val_student_loss: 0.8631
# Epoch 12/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9333 - student_loss: 0.6761 - distillation_loss: 0.2358 - val_sparse_categorical_accuracy: 0.9067 - val_student_loss: 0.7163
# Epoch 13/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9355 - student_loss: 0.6648 - distillation_loss: 0.2408 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.4206
# Epoch 14/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9444 - student_loss: 0.6419 - distillation_loss: 0.2511 - val_sparse_categorical_accuracy: 0.9200 - val_student_loss: 0.4725
# Epoch 15/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9444 - student_loss: 0.6485 - distillation_loss: 0.2430 - val_sparse_categorical_accuracy: 0.8711 - val_student_loss: 0.3777
# Epoch 16/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9399 - student_loss: 0.6368 - distillation_loss: 0.2458 - val_sparse_categorical_accuracy: 0.9022 - val_student_loss: 0.4994
# Epoch 17/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9577 - student_loss: 0.6267 - distillation_loss: 0.2533 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.5857
# Epoch 18/35
# 29/29 [==============================] - 2s 57ms/step - sparse_categorical_accuracy: 0.9488 - student_loss: 0.6301 - distillation_loss: 0.2597 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 2.5015
# Epoch 19/35
# 29/29 [==============================] - 2s 56ms/step - sparse_categorical_accuracy: 0.9611 - student_loss: 0.6205 - distillation_loss: 0.2468 - val_sparse_categorical_accuracy: 0.8933 - val_student_loss: 0.4841
# Epoch 20/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9533 - student_loss: 0.6167 - distillation_loss: 0.2602 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.6762
# Epoch 21/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9655 - student_loss: 0.6152 - distillation_loss: 0.2546 - val_sparse_categorical_accuracy: 0.9067 - val_student_loss: 0.5741
# Epoch 22/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9644 - student_loss: 0.6128 - distillation_loss: 0.2541 - val_sparse_categorical_accuracy: 0.9333 - val_student_loss: 0.4036
# Epoch 23/35
# 29/29 [==============================] - 2s 67ms/step - sparse_categorical_accuracy: 0.9644 - student_loss: 0.6062 - distillation_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9067 - val_student_loss: 0.4081
# Epoch 24/35
# 29/29 [==============================] - 2s 55ms/step - sparse_categorical_accuracy: 0.9689 - student_loss: 0.6072 - distillation_loss: 0.2518 - val_sparse_categorical_accuracy: 0.8800 - val_student_loss: 0.3751
# Epoch 25/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9288 - student_loss: 0.6307 - distillation_loss: 0.2586 - val_sparse_categorical_accuracy: 0.9067 - val_student_loss: 0.4605
# Epoch 26/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9633 - student_loss: 0.6058 - distillation_loss: 0.2654 - val_sparse_categorical_accuracy: 0.9156 - val_student_loss: 0.4707
# Epoch 27/35
# 29/29 [==============================] - 2s 55ms/step - sparse_categorical_accuracy: 0.9722 - student_loss: 0.6156 - distillation_loss: 0.2525 - val_sparse_categorical_accuracy: 0.9333 - val_student_loss: 0.7202
# Epoch 28/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.9800 - student_loss: 0.5982 - distillation_loss: 0.2544 - val_sparse_categorical_accuracy: 0.9244 - val_student_loss: 0.9566
# Epoch 29/35
# 29/29 [==============================] - 2s 63ms/step - sparse_categorical_accuracy: 0.9755 - student_loss: 0.5828 - distillation_loss: 0.2709 - val_sparse_categorical_accuracy: 0.9422 - val_student_loss: 0.6923
# Epoch 30/35
# 29/29 [==============================] - 2s 58ms/step - sparse_categorical_accuracy: 0.9800 - student_loss: 0.5984 - distillation_loss: 0.2516 - val_sparse_categorical_accuracy: 0.8844 - val_student_loss: 0.5916
# Epoch 31/35
# 29/29 [==============================] - 2s 59ms/step - sparse_categorical_accuracy: 0.9633 - student_loss: 0.6039 - distillation_loss: 0.2623 - val_sparse_categorical_accuracy: 0.9378 - val_student_loss: 0.2451
# Epoch 32/35
# 29/29 [==============================] - 2s 62ms/step - sparse_categorical_accuracy: 0.9744 - student_loss: 0.5912 - distillation_loss: 0.2605 - val_sparse_categorical_accuracy: 0.9378 - val_student_loss: 0.5639
# Epoch 33/35
# 29/29 [==============================] - 2s 59ms/step - sparse_categorical_accuracy: 0.9789 - student_loss: 0.5878 - distillation_loss: 0.2597 - val_sparse_categorical_accuracy: 0.9289 - val_student_loss: 0.7511
# Epoch 34/35
# 29/29 [==============================] - 2s 61ms/step - sparse_categorical_accuracy: 0.9766 - student_loss: 0.5893 - distillation_loss: 0.2626 - val_sparse_categorical_accuracy: 0.9333 - val_student_loss: 0.5956
# Epoch 35/35
# 29/29 [==============================] - 2s 60ms/step - sparse_categorical_accuracy: 0.9833 - student_loss: 0.5793 - distillation_loss: 0.2613 - val_sparse_categorical_accuracy: 0.9378 - val_student_loss: 0.6246
# Training execution time (mins) 1.0526578585306803
# 8/8 [==============================] - 0s 32ms/step - sparse_categorical_accuracy: 0.9378 - student_loss: 0.6373
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# {'sparse_categorical_accuracy': 0.9377777576446533, 'student_loss': 0.5695962309837341}

# %% [markdown]
# ## **<font color="#A41034">Compare All Models</font>**

# %%
models_folder = "models" # distil_models / models
models_metrics_list = glob(models_folder+"/*_metrics.json")

all_models_metrics = []
for mm_file in models_metrics_list:
  with open(mm_file) as json_file:
    model_metrics = json.load(json_file)
    model_metrics["name"] = mm_file.replace(models_folder+"/","").replace("_model_metrics.json","")
    all_models_metrics.append(model_metrics)

# Load metrics to dataframe
view_metrics = pd.DataFrame(data=all_models_metrics)

# Format columns
view_metrics['accuracy'] = view_metrics['accuracy']*100
view_metrics['accuracy'] = view_metrics['accuracy'].map('{:,.2f}%'.format)

view_metrics['trainable_parameters'] = view_metrics['trainable_parameters'].map('{:,.0f}'.format)
view_metrics['execution_time'] = view_metrics['execution_time'].map('{:,.2f} mins'.format)
view_metrics['loss'] = view_metrics['loss'].map('{:,.2f}'.format)
view_metrics['model_size'] = view_metrics['model_size']/1000000
view_metrics['model_size'] = view_metrics['model_size'].map('{:,.3f} MB'.format)

view_metrics = view_metrics.sort_values(by=['accuracy'],ascending=False)
view_metrics.head()
# Out:
#   trainable_parameters execution_time   loss accuracy model_size  \
# 2               13,940      1.05 mins   0.57   93.78%   0.077 MB
# 1               13,940      1.13 mins   0.20   92.89%   0.077 MB
# 3               13,940      1.11 mins   0.50   92.44%   0.077 MB
# 0               13,940      0.20 mins   0.57   78.67%   0.209 MB
# 4               82,244      1.74 mins  18.07   32.44%   9.948 MB
#
#    learning_rate  batch_size  epochs optimizer              name
# 2          0.001          32      35      Adam  student_online_a
# 1          0.001          32      35      Adam   student_distill
# 3          0.001          32      35      Adam  student_online_2
# 0          0.001          32       5      Adam   student_scratch
# 4          0.001          32      53       SGD     teacher_model

# %% [markdown]
# # Pruning

# %% [markdown]
# ## **<font color="#A41034">Pruning</font>**

# %% [markdown]
# We can compress a model by model pruning. Pruning is where we set the weights of a network connection to zero for those which have a very small value. This can help reduce the size of the model

# %% [markdown]
# #### **Train Model from Scratch**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 5

# Free up memory
K.clear_session()

# Build the model
before_prune = build_student_model(image_height, image_width, num_channels, num_classes, model_name='before_prune')
print(before_prune.summary())

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Loss
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
before_prune.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=[keras.metrics.SparseCategoricalAccuracy()])

# Train model
start_time = time.time()
training_results = before_prune.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

# Get model training history
training_history = training_results.history

# Evaluate model
evaluate_model(student_model_scratch,validation_data, training_history,execution_time,
               learning_rate, batch_size, epochs, optimizer,
               save=False,
               loss_metrics=["loss","val_loss"],
               acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])
# Out:
# Model: "before_prune"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 8)       224
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/5
# 29/29 [==============================] - 2s 58ms/step - loss: 1.1321 - sparse_categorical_accuracy: 0.4861 - val_loss: 0.8915 - val_sparse_categorical_accuracy: 0.5644
# Epoch 2/5
# 29/29 [==============================] - 2s 55ms/step - loss: 0.6479 - sparse_categorical_accuracy: 0.7764 - val_loss: 0.5746 - val_sparse_categorical_accuracy: 0.8089
# Epoch 3/5
# 29/29 [==============================] - 2s 57ms/step - loss: 0.5289 - sparse_categorical_accuracy: 0.8053 - val_loss: 0.5420 - val_sparse_categorical_accuracy: 0.8044
# Epoch 4/5
# 29/29 [==============================] - 2s 59ms/step - loss: 0.4342 - sparse_categorical_accuracy: 0.8598 - val_loss: 0.5717 - val_sparse_categorical_accuracy: 0.7956
# Epoch 5/5
# 29/29 [==============================] - 2s 58ms/step - loss: 0.4250 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.5173 - val_sparse_categorical_accuracy: 0.7956
# Training execution time (mins) 0.1528652350107829
# 8/8 [==============================] - 1s 59ms/step - loss: 0.5744 - sparse_categorical_accuracy: 0.7778
# {'loss': 0.5743635296821594, 'sparse_categorical_accuracy': 0.7777777910232544}
# [0.5743635296821594, 0.7777777910232544]

# %% [markdown]
# #### **Analyze Model Weights**
#
# Check how many weigths are zero. Usually most weights in a network have a very small values but are not zero.

# %%
def check_model_weights(model):
  for i, w in enumerate(model.get_weights()):
    print(model.weights[i].name,"Total:",w.size, "Zeros:", round(np.sum(np.abs(w) <= 0.01) / w.size * 100,6),"%")

check_model_weights(before_prune)
# Out:
# conv2d/kernel:0 Total: 216 Zeros: 5.092593 %
# conv2d/bias:0 Total: 8 Zeros: 25.0 %
# conv2d_1/kernel:0 Total: 1152 Zeros: 5.902778 %
# conv2d_1/bias:0 Total: 16 Zeros: 18.75 %
# dense/kernel:0 Total: 12544 Zeros: 20.328444 %
# dense/bias:0 Total: 4 Zeros: 0.0 %

# %% [markdown]
# #### **Model Size on Disk**
#
# A simple way to ship models is to `zip` the model file. If we `zip` the model before pruning we see that there is not much difference.

# %%
def compare_model_sizes(model):
  _, model_file = tempfile.mkstemp(".h5")
  tf.keras.models.save_model(model, model_file, include_optimizer=False)
  # Zip the .h5 model file
  _, zip3 = tempfile.mkstemp(".zip")
  with zipfile.ZipFile(zip3, "w", compression=zipfile.ZIP_DEFLATED) as f:
      f.write(model_file)
  print("Model before zip: %.2f Kb"% (os.path.getsize(model_file) / float(1000)))
  print("Model after zip: %.2f Kb"% (os.path.getsize(zip3) / float(1000)))

# %%
compare_model_sizes(before_prune)
# Out:
# Model before zip: 77.27 Kb
# Model after zip: 54.54 Kb
# <ipython-input-21-1168e40d23f9>:3: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   tf.keras.models.save_model(model, model_file, include_optimizer=False)

# %% [markdown]
# #### **Prune Model**
#
# Now we use the tf optimization library to prune our model

# %%
# Define model for pruning
epochs = 5
end_step = np.ceil(len(train_x) / batch_size).astype(np.int32) * epochs

pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step)
}
model_for_pruning = prune_low_magnitude(before_prune, **pruning_params)

# Optimizer
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Loss
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
model_for_pruning.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=[keras.metrics.SparseCategoricalAccuracy()])

model_for_pruning.summary()

# Callback
callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep()
]

# Train
start_time = time.time()
training_results = model_for_pruning.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs,
        callbacks=callbacks,
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)
# Out:
# Model: "before_prune"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv2d  (None, 112, 112, 8)       442
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_  (None, 112, 112, 8)       1
#  re_lu (PruneLowMagnitude)
#
#  prune_low_magnitude_max_po  (None, 56, 56, 8)         1
#  oling2d (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_conv2d  (None, 28, 28, 16)        2322
#  _1 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_  (None, 28, 28, 16)        1
#  re_lu_1 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_max_po  (None, 14, 14, 16)        1
#  oling2d_1 (PruneLowMagnitu
#  de)
#
#  prune_low_magnitude_flatte  (None, 3136)              1
#  n (PruneLowMagnitude)
#
#  prune_low_magnitude_dense   (None, 4)                 25094
#  (PruneLowMagnitude)
#
# =================================================================
# Total params: 27863 (108.87 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 13923 (54.42 KB)
# _________________________________________________________________
# Epoch 1/5
# 29/29 [==============================] - 5s 56ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.8721 - val_loss: 0.5701 - val_sparse_categorical_accuracy: 0.7911
# Epoch 2/5
# 29/29 [==============================] - 2s 57ms/step - loss: 0.3497 - sparse_categorical_accuracy: 0.8899 - val_loss: 0.4577 - val_sparse_categorical_accuracy: 0.8222
# Epoch 3/5
# 29/29 [==============================] - 2s 57ms/step - loss: 0.2979 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.4477 - val_sparse_categorical_accuracy: 0.7867
# Epoch 4/5
# 29/29 [==============================] - 4s 128ms/step - loss: 0.7808 - sparse_categorical_accuracy: 0.7108 - val_loss: 0.7744 - val_sparse_categorical_accuracy: 0.6844
# Epoch 5/5
# 29/29 [==============================] - 2s 57ms/step - loss: 0.5998 - sparse_categorical_accuracy: 0.8287 - val_loss: 0.5623 - val_sparse_categorical_accuracy: 0.8400
# Training execution time (mins) 0.23073141574859618

# %% [markdown]
# #### **Analyze Pruned Weights**

# %%
# Get the model back after pruning
after_prune = tfmot.sparsity.keras.strip_pruning(model_for_pruning)
after_prune.summary()

check_model_weights(after_prune)
# Out:
# Model: "before_prune"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 8)       224
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 8)       0
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 16)        1168
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 4)                 12548
#
# =================================================================
# Total params: 13940 (54.45 KB)
# Trainable params: 13940 (54.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# conv2d/kernel:0 Total: 216 Zeros: 79.166667 %
# conv2d/bias:0 Total: 8 Zeros: 12.5 %
# conv2d_1/kernel:0 Total: 1152 Zeros: 79.079861 %
# conv2d_1/bias:0 Total: 16 Zeros: 25.0 %
# dense/kernel:0 Total: 12544 Zeros: 79.145408 %
# dense/bias:0 Total: 4 Zeros: 25.0 %

# %%
# Get model training history
training_history = training_results.history

# Compile
after_prune.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=[keras.metrics.SparseCategoricalAccuracy()])

# Evaluate model
evaluate_model(after_prune,validation_data, training_history,execution_time,
               learning_rate, batch_size, epochs, optimizer,
               save=True,
               loss_metrics=["loss","val_loss"],
               acc_metrics=["sparse_categorical_accuracy","val_sparse_categorical_accuracy"])
# Out:
# 8/8 [==============================] - 1s 54ms/step - loss: 0.5623 - sparse_categorical_accuracy: 0.8400
# {'loss': 0.5623494982719421, 'sparse_categorical_accuracy': 0.8399999737739563}
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# [0.5623494982719421, 0.8399999737739563]

# %% [markdown]
# #### **Model Size on Disk after Pruning**
#
# Now if we `zip` our model after pruning we see a significant reduction in size.

# %%
compare_model_sizes(after_prune)
# Out:
# Model before zip: 77.27 Kb
# Model after zip: 18.80 Kb
# <ipython-input-21-1168e40d23f9>:3: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   tf.keras.models.save_model(model, model_file, include_optimizer=False)
